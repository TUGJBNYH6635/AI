# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, LeakyReLU, Conv2D
from keras.optimizers import RMSprop
from keras import backend as K
from matplotlib.pyplot import imshow
import numpy as np


(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
#資料的類型轉換
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
#進行正規化動作
x_train /= 255
x_test /= 255

print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Dense(20, activation=LeakyReLU(), input_shape=(784,)))
model.add(Dense(20, activation=LeakyReLU()))
model.add(Dense(10, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=128,
                    epochs=10,
                    verbose=1,
                    validation_data=(x_test, y_test))

scores = model.evaluate(x_test, y_test)
print(scores[1])
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step
# Compression factor: 24.5
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_2 (Dense)              (None, 784)               25872
# =================================================================
# Total params: 50,992
# Trainable params: 50,992
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                25120
# =================================================================
# Total params: 25,120
# Trainable params: 25,120
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 2s 41us/step - loss: 0.2799 - val_loss: 0.1909
# Epoch 2/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.1703 - val_loss: 0.1520
# Epoch 3/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.1432 - val_loss: 0.1332
# Epoch 4/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.1283 - val_loss: 0.1212
# Epoch 5/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.1181 - val_loss: 0.1129
# Epoch 6/50
# 60000/60000 [==============================] - 1s 14us/step - loss: 0.1113 - val_loss: 0.1072
# Epoch 7/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.1063 - val_loss: 0.1028
# Epoch 8/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.1026 - val_loss: 0.0998
# Epoch 9/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0999 - val_loss: 0.0973
# Epoch 10/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0978 - val_loss: 0.0957
# Epoch 11/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0965 - val_loss: 0.0946
# Epoch 12/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0956 - val_loss: 0.0938
# Epoch 13/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0950 - val_loss: 0.0934
# Epoch 14/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0945 - val_loss: 0.0931
# Epoch 15/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0942 - val_loss: 0.0927
# Epoch 16/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0940 - val_loss: 0.0926
# Epoch 17/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0938 - val_loss: 0.0924
# Epoch 18/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0937 - val_loss: 0.0923
# Epoch 19/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0936 - val_loss: 0.0923
# Epoch 20/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0935 - val_loss: 0.0923
# Epoch 21/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0934 - val_loss: 0.0921
# Epoch 22/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0933 - val_loss: 0.0920
# Epoch 23/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0933 - val_loss: 0.0919
# Epoch 24/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0932 - val_loss: 0.0919
# Epoch 25/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0932 - val_loss: 0.0919
# Epoch 26/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0931 - val_loss: 0.0918
# Epoch 27/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0931 - val_loss: 0.0919
# Epoch 28/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0931 - val_loss: 0.0919
# Epoch 29/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 30/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0930 - val_loss: 0.0917
# Epoch 31/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 32/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 33/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 34/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 35/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 36/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 37/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 38/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 39/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 40/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 41/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0928 - val_loss: 0.0918
# Epoch 42/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 43/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 44/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 45/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 46/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 47/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 48/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 49/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 50/50
# 60000/60000 [==============================] - 1s 13us/step - loss: 0.0927 - val_loss: 0.0916
